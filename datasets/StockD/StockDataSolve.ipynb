# %%
import sys
sys.path.append('/home/wbyan/stock_data/')

import numpy as np
import pickle
from data_utils import load_data #会显示报错，但是上面加了sys path可以使用
#读取股市数据

# %%
name="csi500"

date_list, features, labels, stock_list = load_data(
        data_type="ch_daily_processed",
        stock_list=name,
        start_date="2005-01-01",
        end_date="2025-01-01",
        contain_bj=False,
        drop_short=False,
        short_len=1000,
)
# Out:
# ch_daily_processed csi500
# Using the constituent stocks of market index CSI500.
# stock list len is  500
# 100%|██████████| 500/500 [00:00<00:00, 963.01it/s]
# Load stock 603049.SH failed.
# Load stock 001221.SZ failed.
# Use 498 stock, del 2 stock
# 100%|██████████| 498/498 [00:06<00:00, 80.88it/s]
# 100%|██████████| 498/498 [00:00<00:00, 973.19it/s]
# 100%|██████████| 498/498 [00:00<00:00, 2063.59it/s]
# feature tensor shape:torch.Size([498, 4823, 45]), label tensor shape:torch.Size([498, 4823, 4]).

# %%
tmpl=96
outl=5
selectk=500

# %%
features = features.permute(1,0,2)
labels = labels.permute(1,0,2)

# %%
import torch

indix1 = torch.where(features[0,:,0]!=0,1,0)

indix2 = torch.where(features[-1,:,0]!=0,1,0)

indix = (indix1*indix2).nonzero().flatten()

print(indix.shape)

print(features[0,indix,1][:100])
# Out:
# torch.Size([166])
# tensor([-0.0587,  0.0087, -0.0169, -0.0573, -0.0115, -0.0730, -0.0286, -0.0124,
#         -0.0460, -0.0199, -0.0147, -0.0108, -0.0186, -0.0220, -0.0265, -0.0219,
#         -0.0018, -0.0407, -0.0287, -0.0025,  0.0021,  0.0117,  0.0194, -0.0038,
#         -0.0105, -0.0114, -0.0362, -0.0842,  0.0000, -0.0081,  0.0000, -0.0081,
#         -0.0215, -0.0220, -0.0062, -0.0165, -0.0217,  0.0100, -0.0093,  0.0363,
#         -0.0300,  0.0089, -0.0166,  0.0202, -0.0150, -0.0104, -0.0304, -0.0121,
#          0.0126,  0.0000, -0.0100, -0.0108,  0.0033, -0.0149,  0.0000, -0.0278,
#         -0.0093,  0.0355,  0.0142, -0.0361,  0.0039, -0.0182, -0.0088, -0.0128,
#         -0.0359, -0.0319, -0.0077, -0.0175, -0.0162, -0.0312, -0.0354, -0.0302,
#         -0.0133, -0.0169, -0.0150, -0.0055, -0.0018, -0.0188, -0.0174,  0.0000,
#         -0.0110, -0.0205, -0.0172, -0.0363, -0.0200, -0.0421, -0.0021, -0.0074,
#         -0.0322, -0.0282, -0.0286, -0.0059, -0.0636,  0.0054,  0.0016,  0.0139,
#         -0.0174, -0.0428, -0.0312, -0.0421], dtype=torch.float64)

# %%
print(features[0,indix,12])

tmp = torch.sum(features[:,indix,12],dim=0)

print(tmp.shape)

index = torch.topk(tmp,k=selectk)[1].flatten()

print(indix[index])
# Out:
# tensor([2.3530, 1.8718, 1.7435, 1.1997, 1.1963, 2.2413, 0.7635, 1.3708, 2.2831,
#         0.8191, 0.2786, 1.5762, 1.8068, 3.6119, 1.5458, 0.8199, 0.6586, 3.2553,
#         2.1870, 1.4783, 0.9573, 0.9256, 0.6599, 1.0280, 1.7333, 3.7211, 1.4800,
#         3.1860, 0.7819, 2.2018, 1.2642, 3.5801, 2.2148, 1.0837, 3.5920, 0.6758,
#         2.0674, 0.9255, 3.2244, 1.3711, 2.7789, 1.3074, 2.9780, 0.9288, 1.3499,
#         0.7150, 3.3603, 0.9659, 0.9131, 4.2603, 3.6587, 1.9610, 1.9068, 0.5922,
#         0.7331, 1.7460, 0.5836, 3.1302, 0.5701, 1.5545, 1.0074, 1.4284, 0.9426,
#         1.5851, 3.5268, 0.9231, 0.4302, 3.6808, 0.5233, 2.1168, 0.1262, 3.2442,
#         1.5189, 2.1175, 1.7108, 1.4459, 1.5177, 1.1896, 0.7259, 1.4000, 1.4743,
#         0.7612, 2.6758, 1.8443, 0.3833, 0.7931, 1.4261, 0.4367, 0.6226, 1.1871,
#         1.1200, 0.5383, 2.3499, 0.8969, 1.3406, 0.5622, 3.2547, 2.3416, 1.2043,
#         3.1425, 0.9052, 3.8779, 1.4967, 1.4072, 2.9415, 2.8355, 0.9178, 0.5486,
#         3.3063, 1.0068, 1.1006, 1.2458, 0.9977, 0.3155, 2.7939, 3.6703, 1.0188,
#         1.3746, 2.0475, 4.6843, 1.8332, 3.0618, 1.3163, 0.4302, 0.8431, 0.8115,
#         0.9395, 1.0970, 1.3919, 0.9372, 1.9241, 0.8690, 0.2304, 2.4880, 2.0548,
#         1.1264, 0.8040, 3.2636, 3.0396, 2.4451, 2.8648, 1.6402, 0.9769, 2.4702,
#         1.0571, 1.5775, 0.3064, 0.7460, 1.2361, 2.0917, 1.3692, 0.8024, 1.7559,
#         1.1526, 4.1940, 0.3532, 0.7193, 0.6604, 1.3616, 0.3164, 1.1753, 1.8083,
#         1.0498, 1.1209, 0.8021, 1.1261], dtype=torch.float64)
# torch.Size([166])
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /home/benyan2023/workspace/STEP/STEP/datasets/StockD/StockDataSolve.ipynb 单元格 6 line 7
#       <a href='vscode-notebook-cell://ssh-remote%2B10.129.167.112/home/benyan2023/workspace/STEP/STEP/datasets/StockD/StockDataSolve.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> tmp = torch.sum(features[:,indix,12],dim=0)
#       <a href='vscode-notebook-cell://ssh-remote%2B10.129.167.112/home/benyan2023/workspace/STEP/STEP/datasets/StockD/StockDataSolve.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> print(tmp.shape)
# ----> <a href='vscode-notebook-cell://ssh-remote%2B10.129.167.112/home/benyan2023/workspace/STEP/STEP/datasets/StockD/StockDataSolve.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a> index = torch.topk(tmp,k=selectk)[1].flatten()
#       <a href='vscode-notebook-cell://ssh-remote%2B10.129.167.112/home/benyan2023/workspace/STEP/STEP/datasets/StockD/StockDataSolve.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a> print(indix[index])
#
# RuntimeError: selected index k out of range

# %%
print(features.shape)
feature = features[:,indix[index],:]
# Out:
# torch.Size([4823, 4977, 45])

# %%
print(feature.shape)
print(feature[-1,:,1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/benyan2023/workspace/STEP/STEP/datasets/StockD/StockDataSolve.ipynb 单元格 8 line 1
# ----> <a href='vscode-notebook-cell://ssh-remote%2B10.129.167.112/home/benyan2023/workspace/STEP/STEP/datasets/StockD/StockDataSolve.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> print(feature.shape)
#       <a href='vscode-notebook-cell://ssh-remote%2B10.129.167.112/home/benyan2023/workspace/STEP/STEP/datasets/StockD/StockDataSolve.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> print(feature[-1,:,1])
#
# NameError: name 'feature' is not defined

# %%
print(features.shape)
# print(labels[0,:,3])
# Out:
# (4823, 498, 45)

# %%
# orifeatures = load_data(
#         data_type="ch_daily_origin",
#         stock_list="csi500",
#         start_date="2010-01-01",
#         end_date="2010-01-07",
#         contain_bj=False,
#         drop_short=False,
#         short_len=0,    
# )

# %%
# qwq = orifeatures[1]
# print(qwq[:,0,1])

# %%
# print(features.shape)
# random = 1000
# for i in range(12):
#     print(features[i+random][1][:6])
# print(f"ans is {features[10+random][1][4]/features[random][1][4] - 1}")
# print(f"ans is {features[9+random][1][4]/features[random-1][1][4] - 1}")

# %%
# sys.path.append('/home/benyan2023/workspace/STEP/STEP/basicts')
# from utils import load_pkl
# data = load_pkl('data_in144_out12.pkl')
# print(features.shape)
# random = 1000
# ans = 1
# # daily_return  = 0
# # sum = 0
# for i in range(10):
#     ans = ans * (1 + features[i+random][1][1])
#     # daily_return = (features[i+random+1][1][4] - features[i+random][1][4]) / features[i+random][1][4] * 100
#     # sum = sum + daily_return
#     print(features[i+random][1][:5])
#     # print(f"daily_return : {daily_return}")
# # sum = sum / 10
# print(f"ans is {ans}")
# print(labels[random][1])

# %%
# print(features[2,700])
# print(features.shape)
# features = features.permute(1,0,2)
# print(features[700,2])
labels  = labels.numpy()
try :
    features=feature.numpy()
except:
    print("no selection and clean")
    features=features.numpy()
# Out:
# no selection and clean

# %%
file_name = f'data_in{tmpl}_out{outl}_{name}.pkl'
data = {'processed_data':features}
with open(file_name, 'wb') as file:
    pickle.dump(data, file)

# %%
print(data['processed_data'][2][3])
# Out:
# [ 1.08225108e-02 -8.56531049e-03  1.17773019e-02 -9.63597430e-03
#  -8.56531049e-03  0.00000000e+00 -1.11349036e-02 -9.42184154e-03
#  -9.27908637e-03 -1.03319058e-02 -5.18201285e-03 -1.03848434e+00
#   2.68850554e+00  2.65383656e+00  2.72400000e-01  2.72400000e-01
#   1.34000000e+00 -2.34100000e-01 -2.34100000e-01 -2.24000000e-02
#  -2.42000000e-02 -2.42000000e-02  4.00000000e+02  4.00000000e+02
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00 -1.00000000e-01 -1.00000000e-01
#   1.00000000e+00]

# %%
labels = labels[:,indix[index],:]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/benyan2023/workspace/STEP/STEP/datasets/StockD/StockDataSolve.ipynb 单元格 17 line 1
# ----> <a href='vscode-notebook-cell://ssh-remote%2B10.129.167.112/home/benyan2023/workspace/STEP/STEP/datasets/StockD/StockDataSolve.ipynb#X22sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> labels = labels[:,indix[index],:]
#
# NameError: name 'index' is not defined

# %%
print(labels.shape)
# Out:
# (4823, 498, 4)

# %%
file_name = f'label_in{tmpl}_out{outl}_{name}.pkl'
data = {'processed_data':labels}
with open(file_name, 'wb') as file:
    pickle.dump(data, file)

# %%
# tmpl = 144
length = features.shape[0]-tmpl-outl
testl = int(245)
validl = int(245)
trainl = int(length)-testl-validl
# trainl = 8
# testl = 8
# validl = 8
# print(trainl,testl,validl)

, 225), (125, 221, 226), (126, 222, 227), (127, 223, 228), (128, 224, 229), (129, 225, 230), (130, 226, 231), (131, 227, 232), (132, 228, 233), (133, 229, 234), (134, 230, 235), (135, 231, 236), (136, 232, 237), (137, 233, 238), (138, 234, 239), (139, 235, 240), (140, 236, 241), (141, 237, 242), (142, 238, 243), (143, 239, 244), (144, 240, 245), (145, 241, 246), (146, 242, 247), (147, 243, 248), (148, 244, 249), (149, 245, 250), (150, 246, 251), (151, 247, 252), (152, 248, 253), (153, 249, 254), (154, 250, 255), (155, 251, 256), (156, 252, 257), (157, 253, 258), (158, 254, 259), (159, 255, 260), (160, 256, 261), (161, 257, 262), (162, 258, 263), (163, 259, 264), (164, 260, 265), (165, 261, 266), (166, 262, 267), (167, 263, 268), (168, 264, 269), (169, 265, 270), (170, 266, 271), (171, 267, 272), (172, 268, 273), (173, 269, 274), (174, 270, 275), (175, 271, 276), (176, 272, 277), (177, 273, 278), (178, 274, 279), (179, 275, 280), (180, 276, 281), (181, 277, 282), (182, 278, 283), (183, 279, 284), (184, 280, 285), (185, 281, 286), (186, 282, 287), (187, 283, 288), (188, 284, 289), (189, 285, 290), (190, 286, 291), (191, 287, 292), (192, 288, 293), (193, 289, 294), (194, 290, 295), (195, 291, 296), (196, 292, 297), (197, 293, 298), (198, 294, 299), (199, 295, 300), (200, 296, 301), (201, 297, 302), (202, 298, 303), (203, 299, 304), (204, 300, 305), (205, 301, 306), (206, 302, 307), (207, 303, 308), (208, 304, 309), (209, 305, 310), (210, 306, 311), (211, 307, 312), (212, 308, 313), (213, 309, 314), (214, 310, 315), (215, 311, 316), (216, 312, 317), (217, 313, 318), (218, 314, 319), (219, 315, 320), (220, 316, 321), (221, 317, 322), (222, 318, 323), (223, 319, 324), (224, 320, 325), (225, 321, 326), (226, 322, 327), (227, 323, 328), (228, 324, 329), (229, 325, 330), (230, 326, 331), (231, 327, 332), (232, 328, 333), (233, 329, 334), (234, 330, 335), (235, 331, 336), (236, 332, 337), (237, 333, 338), (238, 334, 339), (239, 335, 340), (240, 336, 341), (241, 337, 342), ...
# 4232 245

# %%
scaler = {}
scaler['func']='re_standard_transform'
scaler['args']={'mean': 0, 'std': 1}

file_name = f'scaler_in{tmpl}_out{outl}_{name}.pkl'

with open(file_name,'wb') as file:
    pickle.dump(scaler,file)

# %%
file_name = f'scaler_in{tmpl}_out{outl}_{name}.pkl'
with open(file_name,'rb') as file:
    tmp =  pickle.load(file)
print(tmp)
print(len(train),testl,validl)
# Out:
# {'func': 're_standard_transform', 'args': {'mean': 0, 'std': 1}}
# 4232 245 245

# %%
# file_name = f'index_in800_out20.pkl'
# with open(file_name,'rb') as file:
#     tmp =  pickle.load(file)
# print(len(tmp['valid']))
# Out:
# 487
