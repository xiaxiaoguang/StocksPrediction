# %%
import pickle

import torch
import numpy as np


def load_pkl(pickle_file: str) -> object:
    """Load pickle data.

    Args:
        pickle_file (str): file path

    Returns:
        object: loaded objected
        
    """

    try:
        with open(pickle_file, "rb") as f:
            pickle_data = pickle.load(f)
    except UnicodeDecodeError:
        with open(pickle_file, "rb") as f:
            pickle_data = pickle.load(f, encoding="latin1")
    except Exception as e:
        print("Unable to load data ", pickle_file, ":", e)
        raise
    return pickle_data

data_file_path = "data_in2016_out12.pkl"
data_file_path2 = "data_in12_out12.pkl"

data = load_pkl(data_file_path)
data2 = load_pkl(data_file_path2)

print(data['processed_data'].shape)
# print(data2)
# print(list(data['train'][2]))
# print(type(data))
# print(len(data))
# Out:
# (52116, 325, 3)

# %%
print(data2['processed_data'].shape)
# Out:
# (52116, 325, 3)

# %%
print(data['valid'])
# Out:
# [(21970, 23986, 23998), (21971, 23987, 23999), (21972, 23988, 24000), (21973, 23989, 24001), (21974, 23990, 24002), (21975, 23991, 24003), (21976, 23992, 24004), (21977, 23993, 24005), (21978, 23994, 24006), (21979, 23995, 24007), (21980, 23996, 24008), (21981, 23997, 24009), (21982, 23998, 24010), (21983, 23999, 24011), (21984, 24000, 24012), (21985, 24001, 24013), (21986, 24002, 24014), (21987, 24003, 24015), (21988, 24004, 24016), (21989, 24005, 24017), (21990, 24006, 24018), (21991, 24007, 24019), (21992, 24008, 24020), (21993, 24009, 24021), (21994, 24010, 24022), (21995, 24011, 24023), (21996, 24012, 24024), (21997, 24013, 24025), (21998, 24014, 24026), (21999, 24015, 24027), (22000, 24016, 24028), (22001, 24017, 24029), (22002, 24018, 24030), (22003, 24019, 24031), (22004, 24020, 24032), (22005, 24021, 24033), (22006, 24022, 24034), (22007, 24023, 24035), (22008, 24024, 24036), (22009, 24025, 24037), (22010, 24026, 24038), (22011, 24027, 24039), (22012, 24028, 24040), (22013, 24029, 24041), (22014, 24030, 24042), (22015, 24031, 24043), (22016, 24032, 24044), (22017, 24033, 24045), (22018, 24034, 24046), (22019, 24035, 24047), (22020, 24036, 24048), (22021, 24037, 24049), (22022, 24038, 24050), (22023, 24039, 24051), (22024, 24040, 24052), (22025, 24041, 24053), (22026, 24042, 24054), (22027, 24043, 24055), (22028, 24044, 24056), (22029, 24045, 24057), (22030, 24046, 24058), (22031, 24047, 24059), (22032, 24048, 24060), (22033, 24049, 24061), (22034, 24050, 24062), (22035, 24051, 24063), (22036, 24052, 24064), (22037, 24053, 24065), (22038, 24054, 24066), (22039, 24055, 24067), (22040, 24056, 24068), (22041, 24057, 24069), (22042, 24058, 24070), (22043, 24059, 24071), (22044, 24060, 24072), (22045, 24061, 24073), (22046, 24062, 24074), (22047, 24063, 24075), (22048, 24064, 24076), (22049, 24065, 24077), (22050, 24066, 24078), (22051, 24067, 24079), (22052, 24068, 24080), (22053, 24069, 24081), (22054, 24070, 24082), (22055, 24071, 24083), (22056, 24072, 24084), (22057, 24073, 24085), (22058, 24074, 24086), (22059, 24075, 24087), (22060, 24076, 24088), (22061, 24077, 24089), (22062, 24078, 24090), (22063, 24079, 24091), (22064, 24080, 24092), (22065, 24081, 24093), (22066, 24082, 24094), (22067, 24083, 24095), (22068, 24084, 24096), (22069, 24085, 24097), (22070, 24086, 24098), (22071, 24087, 24099), (22072, 24088, 24100), (22073, 24089, 24101), (22074, 24090, 24102), (22075, 24091, 24103), (22076, 24092, 24104), (22077, 24093, 24105), (22078, 24094, 24106), (22079, 24095, 24107), (22080, 24096, 24108), (22081, 24097, 24109), (22082, 24098, 24110), (22083, 24099, 24111), (22084, 24100, 24112), (22085, 24101, 24113), (22086, 24102, 24114), (22087, 24103, 24115), (22088, 24104, 24116), (22089, 24105, 24117), (22090, 24106, 24118), (22091, 24107, 24119), (22092, 24108, 24120), (22093, 24109, 24121), (22094, 24110, 24122), (22095, 24111, 24123), (22096, 24112, 24124), (22097, 24113, 24125), (22098, 24114, 24126), (22099, 24115, 24127), (22100, 24116, 24128), (22101, 24117, 24129), (22102, 24118, 24130), (22103, 24119, 24131), (22104, 24120, 24132), (22105, 24121, 24133), (22106, 24122, 24134), (22107, 24123, 24135), (22108, 24124, 24136), (22109, 24125, 24137), (22110, 24126, 24138), (22111, 24127, 24139), (22112, 24128, 24140), (22113, 24129, 24141), (22114, 24130, 24142), (22115, 24131, 24143), (22116, 24132, 24144), (22117, 24133, 24145), (22118, 24134, 24146), (22119, 24135, 24147), (22120, 24136, 24148), (22121, 24137, 24149), (22122, 24138, 24150), (22123, 24139, 24151), (22124, 24140, 24152), (22125, 24141, 24153), (22126, 24142, 24154), (22127, 24143, 24155), (22128, 24144, 24156), (22129, 24145, 24157), (22130, 24146, 24158), (22131, 24147, 24159), (22132, 24148, 24160), (22133, 24149, 24161), (22134, 24150, 24162), (22135, 24151, 24163), (22136, 24152, 24164), (22137, 24153, 24165), (22138, 24154, 24166), (22139, 24155, 24167), (22140, 24156, 24168), (22141, 24157, 24169), (22142, 24158, 24170), (22143, 24159, 24171 ...

# %% [raw]
# index_in12_out12 :是用来存放train/test/valid对应的下标的！他也是利用一个三元组（第一个元素为train开始时间，第二个元素为train结束时间，第三个元素为 需要predicted 的结束时间）
#
# 然后data_in12_out12是用来存放具体的时间序列数据，第一维是时间长度第二维变量第三维是特征
#
# 然后scaler里面存了transformes的运行结果，就是数据变换的结果！
#
# adj_mx这个我看不懂，三个元素的list？然后第一个是字符串数组，第二个是一个上面字符数组对应的diction，第三个是个浮点矩阵

# %%
print(len(data['train']))
print(len(data['test']))
print(len(data['valid']))
print(data2['processed_data'].shape)
print(data2['processed_data'])
# Out:
# [[[0.51138941 0.         3.        ]
#   [0.67809983 0.         3.        ]
#   [0.65245208 0.         3.        ]
#   ...
#   [0.2484999  0.         3.        ]
#   [0.74863117 0.         3.        ]
#   [0.38315063 0.         3.        ]]
#
#  [[0.42375958 0.00347222 3.        ]
#   [0.72583316 0.00347222 3.        ]
#   [0.56624712 0.00347222 3.        ]
#   ...
#   [0.07608998 0.00347222 3.        ]
#   [0.72013366 0.00347222 3.        ]
#   [0.43444614 0.00347222 3.        ]]
#
#  [[0.4921536  0.00694444 3.        ]
#   [0.47932972 0.00694444 3.        ]
#   [0.28697154 0.00694444 3.        ]
#   ...
#   [0.35750287 0.00694444 3.        ]
#   [0.79259875 0.00694444 3.        ]
#   [0.38956257 0.00694444 3.        ]]
#
#  ...
#
#  [[0.64604014 0.98958333 2.        ]
#   [0.26987303 0.98958333 2.        ]
#   [0.77712867 0.98958333 2.        ]
#   ...
#   [0.45795659 0.98958333 2.        ]
#   [0.66883814 0.98958333 2.        ]
#   [0.34966606 0.98958333 2.        ]]
#
#  [[0.63321626 0.99305556 2.        ]
#   [0.40238645 0.99305556 2.        ]
#   [0.59474462 0.99305556 2.        ]
#   ...
#   [0.44085808 0.99305556 2.        ]
#   [0.69092371 0.99305556 2.        ]
#   [0.46650584 0.99305556 2.        ]]
#
#  [[0.54914861 0.99652778 2.        ]
#   [0.64034064 0.99652778 2.        ]
#   [0.63464113 0.99652778 2.        ]
#   ...
#   [0.46935559 0.99652778 2.        ]
#   [0.73153266 0.99652778 2.        ]
#   [0.37816356 0.99652778 2.        ]]]

# %%
from easytorch.utils.registry import Registry

SCALER_REGISTRY = Registry("Scaler")
print(SCALER_REGISTRY)
# Out:
# Registry of Scaler:
# {}
